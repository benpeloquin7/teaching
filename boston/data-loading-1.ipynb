# %% [markdown]
# Practice with Boston dataset
#
# **Objective:** Get basic practice with loading data, exploring python objects and creating dataframes.

# %%
# Pandas is a great library for working with structured data
import pandas as pd

# Image() helps for plotting .png files. This isn't important
# to know, but I use it in the notebook
from IPython.display import Image

# os is an important library for using functionality
# from your operating system. It can be very useful for
# dealing with directory and file paths. It's not 
# super important now, but I use it later in the notebook
import os

# sklearn is a library with lots of functionality
# that's useful for datascience and machine learning
# Within sklearn there's a function called `load_boston()` which
# allows us to download a dataset on boston housing
# When in doubt always look for documentation!!! (https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html#sklearn.datasets.load_boston)
from sklearn.datasets import load_boston

# %%
# Let's run the load_boston() function...
data = load_boston()

# %% [markdown]
# ### Question 1. Try to explore the `data` object returned by your call to `load_boston()`
#
# See hints 1-3...

# %%
# ----------------- Your code below


# ----------------- Your code above

# %% [markdown]
# ### Question 2. Using the two fields you found from question 1 create a new pandas data frame
#
# See hints 4-5...

# %%
# ----------------- Your code below
df = pd.DataFrame(...)
# ----------------- Your code above

# %% [markdown]
# If you've created the dataframe correctly you should see something like this when you call `df.head()`

# %%
img_fp = os.path.join(os.getcwd(), "img/df-head.png")
Image(img_fp, width=700)

# %% [markdown]
# ```
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# This is just a place-holder.
# |
# |
# |
# |
# |
# |
# |
# |
# |
# |
# ```

# %% [markdown]
# ### Hints below

# %% [markdown]
# Let's create a pandas data frame and work with that...

# %% [markdown]
# **Hint 1**: The function `type()` can be useful for figuring out what an object is. For example, let's call `type` on a string.
#
# ```
# # You can copy this code in a new cell that has type `code` to test it out
# x = "This is a string"
# type(x) # This should output `str`
# ```
#
#
# ```
# y = 10
# type(y) # This should output `int`
# ```
#
#
# ```
# class Person():
#     def __init__(self, age, name):
#         self.age = age
#         self.age = name
# z = Person("Bob", 59)
# type(z) # This should output `Person`
# ```

# %% [markdown]
# **Hint 2**: The function `dir()` can be useful for figuring out what methods and attributes an object has. Try:
#
# ```
# class Person():
#     def __init__(self, age, name):
#         self.age = age
#         self.name = name
#     def say_hello(self):
#         print("hello world!")
# z = Person("Bob", 59)
# dir(z) # This should output `Person`
# ```

# %% [markdown]
# **Hint 3**: The attribute `.data` contains the actual data and the attribute `.feature_names` contains the column names
#
# ```
# dir(data)
# data.data
# data.feature_names
# ```

# %% [markdown]
# **Hint 4**: There **a few** different ways to construct dataframes in pandas. Check out this document (https://www.geeksforgeeks.org/different-ways-to-create-pandas-dataframe/). I think you'll find `Method #1` pretty useful given the data we get back from `load_boston()`

# %% [markdown]
# **Hint 5**: Here's a couple different ways...
# ```
# (1) df = pd.DataFrame(data.data, columns=data.feature_names)
#
# (2) df = pd.DataFrame({feature: data for feature, data in zip(data.feature_names, data.data)})
# ```
